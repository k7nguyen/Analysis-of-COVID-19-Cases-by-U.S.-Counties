# %% [markdown]
# # Karyn Nguyen, Kate Marvin, Travis Kaufman, Farhan Billah, Guillermo Maltes, Nick Buccino
# ## k7nguyen@scu.edu

# %% [markdown]
# ### Dataset: https://www.kaggle.com/fireballbyedimyrnmom/us-counties-covid-19-dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loads data and shows first n rows to test if object has correct data
df=pd.read_csv("us-counties.csv", index_col="date")
df.head()
# Out:
#                county       state     fips  cases  deaths
# date
# 2020-01-21  Snohomish  Washington  53061.0      1       0
# 2020-01-22  Snohomish  Washington  53061.0      1       0
# 2020-01-23  Snohomish  Washington  53061.0      1       0
# 2020-01-24       Cook    Illinois  17031.0      1       0
# 2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
#Column names
df.columns
# Out:
# Index(['county', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %% [markdown]
# # California: Los Angeles County

# %%
#Shows earliest and latest data for LA County cases
la_df=df[df.county=="Los Angeles"]
la_df
# Out:
#                  county       state    fips  cases  deaths
# date
# 2020-01-26  Los Angeles  California  6037.0      1       0
# 2020-01-27  Los Angeles  California  6037.0      1       0
# 2020-01-28  Los Angeles  California  6037.0      1       0
# 2020-01-29  Los Angeles  California  6037.0      1       0
# 2020-01-30  Los Angeles  California  6037.0      1       0
# ...                 ...         ...     ...    ...     ...
# 2020-06-04  Los Angeles  California  6037.0  59650    2531
# 2020-06-05  Los Angeles  California  6037.0  61045    2565
# 2020-06-06  Los Angeles  California  6037.0  62338    2620
# 2020-06-07  Los Angeles  California  6037.0  63844    2645
# 2020-06-08  Los Angeles  California  6037.0  64644    2655
#
# [135 rows x 5 columns]

# %%
#Line chart of LA County cases from Janaury until now (early June)
ax=la_df.plot(y="cases", figsize=(10,6))
ax.set(xlabel="Date", ylabel="Cases")
plt.title("COVID-19 Cases in Los Angeles County from January to Early June")
# Out:
# Text(0.5, 1.0, 'COVID-19 Cases in Los Angeles County from January to Early June')

# %% [markdown]
# #### This graph displays the overall trend of COVID-19 cases in Los Angeles County. Although the chart shows that the first case in this county occured in late January, the graphs shows that the the number of cases started to increase in late March. Since then, the number of cases have been rapidly increasing and as of early June, the number of cases in LA County is roughly 65,000. An interesting observation seen in this graph is that the county's Shelter-in-Place orders do not seem to have an extremely large negative effect on the number of COVID-19 cases. It is likely that this order kept the number of cases lower than if the order was not implemented, but it has not entirely stopped the virus from spreading.

# %% [markdown]
# # Wyoming: Sweetwater County

# %%
#Shows earliest and latest data for Sweetwater County cases
sweetwater_df=df[df.county=="Sweetwater"]
sweetwater_df
# Out:
#                 county    state     fips  cases  deaths
# date
# 2020-03-24  Sweetwater  Wyoming  56037.0      1       0
# 2020-03-25  Sweetwater  Wyoming  56037.0      1       0
# 2020-03-26  Sweetwater  Wyoming  56037.0      1       0
# 2020-03-27  Sweetwater  Wyoming  56037.0      1       0
# 2020-03-28  Sweetwater  Wyoming  56037.0      1       0
# ...                ...      ...      ...    ...     ...
# 2020-06-04  Sweetwater  Wyoming  56037.0     32       0
# 2020-06-05  Sweetwater  Wyoming  56037.0     32       0
# 2020-06-06  Sweetwater  Wyoming  56037.0     32       0
# 2020-06-07  Sweetwater  Wyoming  56037.0     32       0
# 2020-06-08  Sweetwater  Wyoming  56037.0     33       0
#
# [77 rows x 5 columns]

# %%
#Line chart of Sweetwater County cases from Janaury until now (early June)
ax=sweetwater_df.plot(y="cases", figsize=(10,6))
ax.set(xlabel="Date", ylabel="Cases")
plt.title("COVID-19 Cases in Sweetwater County from January to Early June")
# Out:
# Text(0.5, 1.0, 'COVID-19 Cases in Sweetwater County from January to Early June')

# %% [markdown]
# #### The graph above displays the cases of COVID-19 in the county of Sweetwater, Wyoming. With a small population of 42,343 people, one would expect the number of cases to stay relatively low and generally stay the same over time, since most people would be aware and become cautious early on. Although there is some stagnation, especially during the month of April, the cases continue to rise even to the current day. Thus, although one would predict the virus to be under control in a small county, that seems to not be the case. Another interesting aspect of the graph is the quick shift from decrease in cases to increase in a turn of a couple days. In total, the general trend of this graph seems to predict that the amount of COVID-19 cases will continue to increase, but with the caution being taken, this may not be true and cases may start to decrease especially in small counties, such as Sweetwater.

# %% [markdown]
# # Washington: Spokane County & Snohomish County

# %%
#Shows earliest and latest data for Washington state cases
washingtondf=df[df.state=="Washington"]
washingtondf
# Out:
#                  county       state     fips  cases  deaths
# date
# 2020-01-21    Snohomish  Washington  53061.0      1       0
# 2020-01-22    Snohomish  Washington  53061.0      1       0
# 2020-01-23    Snohomish  Washington  53061.0      1       0
# 2020-01-24    Snohomish  Washington  53061.0      1       0
# 2020-01-25    Snohomish  Washington  53061.0      1       0
# ...                 ...         ...      ...    ...     ...
# 2020-06-08    Wahkiakum  Washington  53069.0      4       0
# 2020-06-08  Walla Walla  Washington  53071.0    117       2
# 2020-06-08      Whatcom  Washington  53073.0    419      37
# 2020-06-08      Whitman  Washington  53075.0     26       0
# 2020-06-08       Yakima  Washington  53077.0   4929     101
#
# [3304 rows x 5 columns]

# %%
#Shows earliest and latest data for Spokane County cases
spokanedf=washingtondf[washingtondf.county=="Spokane"]
spokanedf
# Out:
#              county       state     fips  cases  deaths
# date
# 2020-02-24  Spokane  Washington  53063.0      4       0
# 2020-02-25  Spokane  Washington  53063.0      4       0
# 2020-02-26  Spokane  Washington  53063.0      4       0
# 2020-02-27  Spokane  Washington  53063.0      4       0
# 2020-02-28  Spokane  Washington  53063.0      4       0
# ...             ...         ...      ...    ...     ...
# 2020-06-04  Spokane  Washington  53063.0    652      34
# 2020-06-05  Spokane  Washington  53063.0    711      35
# 2020-06-06  Spokane  Washington  53063.0    717      35
# 2020-06-07  Spokane  Washington  53063.0    740      35
# 2020-06-08  Spokane  Washington  53063.0    767      35
#
# [106 rows x 5 columns]

# %%
#Shows earliest and latest data for Snohomish County cases
snohomishdf=washingtondf[washingtondf.county=="Snohomish"]
snohomishdf
# Out:
#                county       state     fips  cases  deaths
# date
# 2020-01-21  Snohomish  Washington  53061.0      1       0
# 2020-01-22  Snohomish  Washington  53061.0      1       0
# 2020-01-23  Snohomish  Washington  53061.0      1       0
# 2020-01-24  Snohomish  Washington  53061.0      1       0
# 2020-01-25  Snohomish  Washington  53061.0      1       0
# ...               ...         ...      ...    ...     ...
# 2020-06-04  Snohomish  Washington  53061.0   3442     152
# 2020-06-05  Snohomish  Washington  53061.0   3471     151
# 2020-06-06  Snohomish  Washington  53061.0   3472     152
# 2020-06-07  Snohomish  Washington  53061.0   3471     151
# 2020-06-08  Snohomish  Washington  53061.0   3504     152
#
# [140 rows x 5 columns]

# %%
#Line chart of Spokane and Snohomish cases from Janaury until now (early June)
dataframe={"date": snohomishdf.index, "Spokane": [], "Snohomish": []}

for i in snohomishdf.index:
    if i in spokanedf.index:
        dataframe["Spokane"].append(spokanedf.loc[i, "cases"])
    else:
        dataframe["Spokane"].append(0)
        
    dataframe['Snohomish'].append(snohomishdf.loc[i]['cases'])

graphdf=pd.DataFrame.from_dict(dataframe)

ax=graphdf.plot(x="date", y=["Spokane", "Snohomish"], figsize=(10,6))
ax.set(xlabel="Date", ylabel="Cases")
plt.title("COVID-19 Cases in Spokane & Snohomish from January to Early June")
# Out:
# Text(0.5, 1.0, 'COVID-19 Cases in Spokane & Snohomish from January to Early June')

# %% [markdown]
# #### This graph shows the number of cases in Spokane compared to the number of cases in Snohomish from January to early June. In  early/mid March, Snohomish began to report a surplus of cases, while Spokane remained constant until early April. Since then, it seems that Snohomish continues to report throusands more cases than Spokane. However, both seem to have an upward trend.
